# %%
import pandas as pd

df = pd.read_csv("short_test_data.csv")

# %%
df.head()
# Out:
#         MMSI         BaseDateTime       LAT        LON  SOG    COG  Heading  \
# 0  338075892  2024-01-01 00:00:03  43.65322  -70.25298  0.0  358.8    511.0
# 1  367669550  2024-01-01 00:00:04  46.20031 -123.38573  0.0  281.9    141.0
# 2  367118980  2024-01-01 00:00:06  29.98534  -90.40674  0.0   30.1    296.0
# 3  367177840  2024-01-01 00:00:05  39.88654  -75.17649  0.0  304.4    511.0
# 4  367305420  2024-01-01 00:00:06  18.33273  -64.95229  0.0  332.6    511.0
#
#              VesselName         IMO CallSign  VesselType  Status  Length  \
# 0  PILOT BOAT SPRING PT         NaN  WDB8945        90.0     0.0     0.0
# 1     ALASKA CHALLENGER  IMO7938024  WDH9586        30.0    15.0    30.0
# 2       CAPT J A MORGAN  IMO1186680  WDD2725        31.0    12.0   115.0
# 3         BART TURECAMO  IMO7338808  WBR4464        52.0    15.0    33.0
# 4         DOROTHY MORAN  IMO7716995  WXU4654        52.0     0.0    33.0
#
#    Width  Draft  Cargo TransceiverClass
# ...
